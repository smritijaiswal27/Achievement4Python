# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\smrit\Intracart basket'

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(path,  'Prepared', 'orders_products_merged_update.pkl'))

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#    Unnamed: 0_y  product_name  aisle_id department_id  prices  true  \
# 0           195          Soda        77             7     9.0  both
# 1           195          Soda        77             7     9.0  both
# 2           195          Soda        77             7     9.0  both
# 3           195          Soda        77             7     9.0  both
# 4           195          Soda        77             7     9.0  both
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly days        Average orders
# 1  Mid-range product  Regularly busy    Slowest days        Average orders
# 2  Mid-range product  Regularly busy    Slowest days           Most orders
# 3  Mid-range product      Least busy    Slowest days        Average orders
# 4  Mid-range product      Least busy    Slowest days           Most orders
#
# [5 rows x 22 columns]

# %%
# Creating subset

df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
# 5             5             5   3367565        1    prior             6
# 6             6             6    550135        1    prior             7
# 7             7             7   3108588        1    prior             8
# 8             8             8   2295261        1    prior             9
# 9             9             9   2550362        1    prior            10
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
# 5          2                  7                    19.0         196  ...
# 6          1                  9                    20.0         196  ...
# 7          1                 14                    14.0         196  ...
# 8          1                 16                     0.0         196  ...
# 9          4                  8                    30.0         196  ...
#
#    Unnamed: 0_y  product_name  aisle_id department_id  prices  true  \
# 0           195          Soda        77             7     9.0  both
# 1           195          Soda        77             7     9.0  both
# 2           195          Soda        77             7     9.0  both
# 3           195          Soda        77             7     9.0  both
# 4           195          Soda        77             7     9.0  both
# 5           195          Soda        77             7     9.0  both
# 6           195          Soda        77             7     9.0  both
# 7           195          Soda        77             7     9.0  both
# 8           195          Soda        77             7     9.0  both
# 9           195          Soda        77             7     9.0  both
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly days        Average orders
# 1  Mid-range product  Regularly busy    Slowest days        Average orders
# 2  Mid-range product  Regularly busy    Slowest days           Most orders
# 3  Mid-range product      Least busy    Slowest days        Average orders
# 4  Mid-range product      Least busy    Slowest days           Most orders
# 5  Mid-range product  Regularly busy  Regularly days        Average orders
# 6  Mid-range product  Regularly busy    Busiest days        Average orders
# 7  Mid-range product  Regularly busy    Busiest days           Most orders
# 8  Mid-range product  Regularly busy    Busiest days        Average orders
# 9  Mid-range product      Least busy    Slowest days        Average orders
#
# [10 rows x 22 columns]

# %%
###Grouping Data with Pandas

# %%
df.groupby('product_name')

# %%
# To recap, you should always use the groupby() function as part of a series of steps, namely, the following:

# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# So far, you’ve only completed the first step—splitting the data into groups (with the group being the “product_name” column)

# %%
#Single aggregation
#Aggregating Data with agg()
###To recap, you should always use the groupby() function as part of a series of steps, namely, the following:

# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# So far, you’ve only completed the first step—splitting the data into groups (with the group being the “product_name” column)

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.974233
# 3                18.300079
# 4                18.765849
# 6                16.470395
# 7                17.890720
# 11               21.682310
# 12               16.924342
# 13               17.907075
# 14               16.964049
# 15               18.233493
# 16               18.116992
# 17               10.552279
# 19               17.504216
# 20               17.251314

# %%
# Different way of finding mean of 'order_number'

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.974233
# 3     18.300079
# 4     18.765849
# 6     16.470395
# 7     17.890720
# 11    21.682310
# 12    16.924342
# 13    17.907075
# 14    16.964049
# 15    18.233493
# 16    18.116992
# 17    10.552279
# 19    17.504216
# 20    17.251314
# Name: order_number, dtype: float64

# %%
#Multiple aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.974233   1  99
# 3                18.300079   1  99
# 4                18.765849   1  99
# 6                16.470395   1  90
# 7                17.890720   1  99
# 11               21.682310   1  99
# 12               16.924342   1  95
# 13               17.907075   1  99
# 14               16.964049   1  99
# 15               18.233493   1  99
# 16               18.116992   1  99
# 17               10.552279   1  98
# 19               17.504216   1  99
# 20               17.251314   1  99

# %%
#Aggregating Data with transform

# %%
# Now, let’s map this task onto the three-step process introduced earlier:

# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby('user_id')['order_number'].transform(np.max)
# df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# Let’s run through each piece of the code in turn:
# First, a new column called “max_order” is created, which will be what stores the maximum order number for each user (step 3).
# Then, the df_orders_products_merged dataframe is grouped by the “user_id” column (step 1).
# And finally, the transform() function is applied on the “order_number” column with the np.max argument (step 2).

# %%
df_orders_products_merged.head(25)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# 5              5             5   3367565        1    prior             6
# 6              6             6    550135        1    prior             7
# 7              7             7   3108588        1    prior             8
# 8              8             8   2295261        1    prior             9
# 9              9             9   2550362        1    prior            10
# 10           144           144   2968173       15    prior            15
# 11           146           146   1870022       15    prior            17
# 12           147           147   1911383       15    prior            18
# 13           150           150   2715276       15    prior            21
# 14           151           151    487368       15    prior            22
# 15           209           209   2293453       19    prior             2
# 16           212           212   1973799       19    prior             5
# 17           214           214    532817       19    prior             7
# 18           232           232   1573906       21    prior            10
# 19           458           458   1593000       31    prior            10
# 20           465           465   2231262       31    prior            17
# 21           617           617   2580647       43    prior             6
# 22           620           620   2187180       43    prior             9
# 23           751           751   2497897       52    prior             1
# 24           752           752   1318871       52    prior             2
#
#     order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0           2                  8                     NaN         196  ...
# 1           3                  7                    15.0         196  ...
# 2           3                 12                    21.0         196  ...
# 3           4                  7                    29.0         196  ...
# 4           4                 15                    28.0         196  ...
# 5           2                  7                    19.0         196  ...
# 6           1                  9                    20.0         196  ...
# 7           1                 14                    14.0         196  ...
# 8           1                 16                     0.0         196  ...
# 9           4                  8                    30.0         196  ...
# 10          1                  9                     7.0         196  ...
# 11          2                 16                     8.0         196  ...
# 12          2                 11                     7.0         196  ...
# 13          1                  9                     7.0         196  ...
# 14          1                 10                    14.0         196  ...
# 15          5                 14                     6.0         196  ...
# 16          6                 12                     8.0         196  ...
# 17          4                 17                     6.0         196  ...
# 18          3                 10                     6.0         196  ...
# 19          3                  8                     7.0         196  ...
# 20          3                 11                     8.0         196  ...
# 21          4                 16                     4.0         196  ...
# 22          4                 12                     3.0         196  ...
# 23          1                  9                     NaN         196  ...
# 24          1                 10                     7.0         196  ...
#
#     product_name  aisle_id  department_id prices  true    price_range_loc  \
# 0           Soda        77              7    9.0  both  Mid-range product
# 1           Soda        77              7    9.0  both  Mid-range product
# 2           Soda        77              7    9.0  both  Mid-range product
# 3           Soda        77              7    9.0  both  Mid-range product
# 4           Soda        77              7    9.0  both  Mid-range product
# 5           Soda        77              7    9.0  both  Mid-range product
# 6           Soda        77              7    9.0  both  Mid-range product
# 7           Soda        77              7    9.0  both  Mid-range product
# 8           Soda        77              7    9.0  both  Mid-range product
# 9           Soda        77              7    9.0  both  Mid-range product
# 10          Soda        77              7    9.0  both  Mid-range product
# 11          Soda        77              7    9.0  both  Mid-range product
# 12          Soda        77              7    9.0  both  Mid-range product
# 13          Soda        77              7    9.0  both  Mid-range product
# 14          Soda        77              7    9.0  both  Mid-range product
# 15          Soda        77              7    9.0  both  Mid-range product
# 16          Soda        77              7    9.0  both  Mid-range product
# 17          Soda        77              7    9.0  both  Mid-range product
# 18          Soda        77              7    9.0  both  Mid-range product
# 19          Soda        77              7    9.0  both  Mid-range product
# 20          Soda        77              7    9.0  both  Mid-range product
# 21          Soda        77              7    9.0  both  Mid-range product
# 22          Soda        77              7    9.0  both  Mid-range product
# 23          Soda        77              7    9.0  both  Mid-range product
# 24          Soda        77              7    9.0  both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day max_order
# 0   Regularly busy  Regularly days        Average orders        10
# 1   Regularly busy    Slowest days        Average orders        10
# 2   Regularly busy    Slowest days           Most orders        10
# 3       Least busy    Slowest days        Average orders        10
# 4       Least busy    Slowest days           Most orders        10
# 5   Regularly busy  Regularly days        Average orders        10
# 6   Regularly busy    Busiest days        Average orders        10
# 7   Regularly busy    Busiest days           Most orders        10
# 8   Regularly busy    Busiest days        Average orders        10
# 9       Least busy    Slowest days        Average orders        10
# 10  Regularly busy    Busiest days        Average orders        22
# 11  Regularly busy  Regularly days        Average orders        22
# 12  Regularly busy  Regularly days           Most orders        22
# 13  Regularly busy    Busiest days        Average orders        22
# 14  Regularly busy    Busiest days           Most orders        22
# 15  Regularly busy  Regularly days           Most orders         9
# 16  Regularly busy  Regularly days           Most orders         9
# 17      Least busy    Slowest days        Average orders         9
# 18  Regularly busy    Slowest days           Most orders        33
# 19  Regularly busy    Slowest days        Average orders        20
# 20  Regularly busy    Slowest days           Most orders        20
# 21      Least busy    Slowest days        Average orders        11
# 22      Least busy    Slowest days           Most orders        11
# 23  Regularly busy    Busiest days        Average orders        27
# 24  Regularly busy    Busiest days           Most orders        27
#
# [25 rows x 23 columns]

# %%
# Deriving Columns with loc()
#To create your flag, you’ll need some criteria. You can use the following:

# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_orders_products_merged.loc[(df_orders_products_merged['max_order'] <= 40) & (df_orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    4865587
# Loyal customer      3154279
# New customer        1898387
# Name: loyalty_flag, dtype: int64

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#    aisle_id  department_id  prices  true    price_range_loc     busiest_day  \
# 0        77              7     9.0  both  Mid-range product  Regularly busy
# 1        77              7     9.0  both  Mid-range product  Regularly busy
# 2        77              7     9.0  both  Mid-range product  Regularly busy
# 3        77              7     9.0  both  Mid-range product      Least busy
# 4        77              7     9.0  both  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag
# 0  Regularly days        Average orders        10  New customer
# 1    Slowest days        Average orders        10  New customer
# 2    Slowest days           Most orders        10  New customer
# 3    Slowest days        Average orders        10  New customer
# 4    Slowest days           Most orders        10  New customer
#
# [5 rows x 24 columns]

# %%
# You learned already that to access a single column in a dataframe, you can index it like so: df['column']

# %%
# check the accuracy of the 'loyalty_flag' column with output from columns 'user_id', 'max_order', and 'loyalty_flag' column

df_orders_products_merged[['user_id', 'max_order', 'loyalty_flag']].sample(30)

# The first set of brackets is the same as the brackets used in df['column'] above,
# while the second set of brackets is indicating that what you’re indexing is a list of multiple columns (and lists are always included within brackets).
# This is why there are two sets of brackets.
# Out:
#          user_id  max_order      loyalty_flag
# 5901950    10510         18  Regular customer
# 984801     32578         30  Regular customer
# 8037227    47573         11  Regular customer
# 6470612    13726         16  Regular customer
# 6580106    27902          6      New customer
# 2812188     9764         14  Regular customer
# 845124      1664          3      New customer
# 911265      9903          8      New customer
# 9382330    62453         99    Loyal customer
# 3235702    18551         34  Regular customer
# 8467067    13702          4      New customer
# 3548217    23170         99    Loyal customer
# 5061558    33712         43    Loyal customer
# 5036051     1833         29  Regular customer
# 9421079     1910          8      New customer
# 7804642    29869         16  Regular customer
# 6964150    29234         27  Regular customer
# 2817107    52702         31  Regular customer
# 1781917    21664         44    Loyal customer
# 6735003    60790         23  Regular customer
# 3418349    41760         15  Regular customer
# 4048579    31152          3      New customer
# 9274103     1437          6      New customer
# 1222368     1352         29  Regular customer
# 8135683    11326         16  Regular customer
# 4646061     2474         35  Regular customer
# 8158027    19300         99    Loyal customer
# 3496149    34797         35  Regular customer
# 9107981    40704         39  Regular customer
# 7882718     9978         34  Regular customer

# %%
# And that brings you to the end of the three-step process!
# 1. You started by grouping your data,
# 2. followed up by applying an aggregation function,
# 3. and finished everything off by using the resulting aggregation to create a flag column

# %%
#Task 4.8

# %%
#Step 1

# %%
#Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
#DONE

# %%
#Step 2

# %%
#In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df_orders_products_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.393473
# 2                17.000546
# 3                17.216578
# 4                17.714601
# 5                14.958409
# 6                16.454727
# 7                17.325861
# 8                15.117326
# 9                16.027829
# 10               20.229811
# 11               16.453444
# 12               15.895358
# 13               16.692698
# 14               16.817133
# 15               16.133323
# 16               17.607401
# 17               15.936598
# 18               19.646685
# 19               17.216008
# 20               16.393918
# 21               22.580576

# %%
# This is the subset one (I decided to run again instead of scrolling up)

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.974233
# 3                18.300079
# 4                18.765849
# 6                16.470395
# 7                17.890720
# 11               21.682310
# 12               16.924342
# 13               17.907075
# 14               16.964049
# 15               18.233493
# 16               18.116992
# 17               10.552279
# 19               17.504216
# 20               17.251314

# %%
#Answer: The average result of order_number from the subset (1000000) is greater than the average result of entire dataframe (except the department_id: 17)

# %%
#Step 4

# %%
#Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# DONE (Output [26])

# %%
#Step 5

# %%
#Determine the difference between the spending habits of the three types of customers you identified.
#Determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
print('The mean, min and max of prices grouped by the loyalty_flag column in df_orders_products_merged:')
df_orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# The mean, min and max of prices grouped by the loyalty_flag column in df_orders_products_merged:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     9.435027  1.0  99999.0
# New customer      12.705686  1.0  99999.0
# Regular customer  11.675800  1.0  99999.0

# %%
#Observation:
#1. It is interesting to see that new customers have a higher average purchase price than the other 2 customer categories and even loyal customers have a lower average purchase than the others
#2. The maximum price here seems odd compared to the mean value itself. The value of 99.999 has skewed the distribution so further analysis for this value will be performed.¶

# %%
# Run descriptive statistics on the 'prices' column

print('Descriptive statistics of the prices column:')
df_orders_products_merged['prices'].describe()
# Out:
# Descriptive statistics of the prices column:
# count    9.918253e+06
# mean     1.116030e+01
# std      4.168003e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
#Observation:
#1. The average (mean) price is 11.9 and the maximum price is 99.999, through this we can see that there is a huge difference in this data
#2. The standard deviation has been confirmed which has a std of 495.655 indicating that we have a lot of variation in this data (especially large values that are higher than the mean)¶

# %%
# Check for abnormal values in the 'prices' column

print('Check for abnormal values in the prices column:')
df_orders_products_merged['prices'].sort_values(ascending = False)
# Out:
# Check for abnormal values in the prices column:
# 8934422    99999.0
# 8934436    99999.0
# 8934443    99999.0
# 8934442    99999.0
# 8934441    99999.0
#             ...
# 7210155        1.0
# 7210154        1.0
# 7210153        1.0
# 7210152        1.0
# 2807563        1.0
# Name: prices, Length: 9918253, dtype: float64

# %%
print('Check for abnormal values in the prices column:')

df_orders_products_merged['prices'].drop_duplicates().sort_values(ascending = False)
# Out:
# Check for abnormal values in the prices column:
# 8934387    99999.0
# 3075482    14900.0
# 5671620       25.0
# 7890146       24.9
# 8707834       24.8
#             ...
# 1039169        1.4
# 193634         1.3
# 1685474        1.2
# 1580247        1.1
# 19270          1.0
# Name: prices, Length: 242, dtype: float64

# %%
#Observation: The 99.999 and 14.900 prices look weird (that's a lot higher than the others)

# %%
# Get the output of df_orders_products_merged when the value in the 'prices' column is 99999 or 14900

max_price = df_orders_products_merged.loc[df_orders_products_merged['prices'].isin([99999, 14900])]

# %%
# Sample output:

print('Sample output of df_orders_products_merged when the value in the prices column is either 99999 or 14900:')
max_price.sample(5)
# Out:
# Sample output of df_orders_products_merged when the value in the prices column is either 99999 or 14900:
#          Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 3076366        776436        776436   1218199    46664    prior             5
# 3076722       1017044       1017044    755972    61126    prior             1
# 3075891        317621        317621     69973    19234    prior             5
# 3076690        999255        999255   3364822    60040    prior            41
# 3076644        972976        972976   1660805    58463    prior             1
#
#          order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 3076366          1                 15                     9.0       21553
# 3076722          0                 15                     NaN       21553
# 3075891          0                 15                    30.0       21553
# 3076690          1                  9                     7.0       21553
# 3076644          4                 14                     NaN       21553
#
#          ...  aisle_id  department_id   prices  true     price_range_loc  \
# 3076366  ...       108             16  14900.0  both  High-range product
# 3076722  ...       108             16  14900.0  both  High-range product
# 3075891  ...       108             16  14900.0  both  High-range product
# 3076690  ...       108             16  14900.0  both  High-range product
# 3076644  ...       108             16  14900.0  both  High-range product
#
#             busiest_day  busiest_days busiest_period_of_day max_order  \
# 3076366  Regularly busy  Busiest days           Most orders        34
# 3076722     Busiest day  Busiest days           Most orders         9
# 3075891     Busiest day  Busiest days           Most orders         7
# 3076690  Regularly busy  Busiest days        Average orders        99
# 3076644      Least busy  Slowest days           Most orders        26
#
#              loyalty_flag
# 3076366  Regular customer
# 3076722      New customer
# 3075891      New customer
# 3076690    Loyal customer
# 3076644  Regular customer
#
# [5 rows x 24 columns]

# %%
# Descriptive statistics on max_price

print('Descriptive statistics on max_price:')
max_price.describe()

# I need to scroll to the right to find the price, department_id and product_id
# Out:
# Descriptive statistics on max_price:
#        Unnamed: 0.1  Unnamed: 0_x      order_id       user_id  order_number  \
# count  1.421000e+03  1.421000e+03  1.421000e+03   1421.000000   1421.000000
# mean   5.285181e+05  5.285181e+05  1.673900e+06  31810.187192     13.518649
# std    3.193877e+05  3.193877e+05  9.992504e+05  19167.794112     14.761359
# min    1.710000e+02  1.710000e+02  4.300000e+01     17.000000      1.000000
# 25%    2.304010e+05  2.304010e+05  7.823530e+05  13951.000000      4.000000
# 50%    5.228540e+05  5.228540e+05  1.638303e+06  31532.000000      8.000000
# 75%    8.185610e+05  8.185610e+05  2.558908e+06  49225.000000     18.000000
# max    1.045595e+06  1.045595e+06  3.420827e+06  62924.000000     96.000000
#
#         order_dow  order_hour_of_day  days_since_prior_order    product_id  \
# count  1421.00000        1421.000000             1325.000000   1421.000000
# mean      2.69247          13.446165               12.530566  22780.293455
# std       2.00889           4.184237                9.095167   3656.078296
# min       0.00000           0.000000                0.000000  21553.000000
# 25%       1.00000          10.000000                6.000000  21553.000000
# 50%       2.00000          14.000000                9.000000  21553.000000
# 75%       4.00000          16.000000               18.000000  21553.000000
# max       6.00000          23.000000               30.000000  33664.000000
#
#        add_to_cart_order    reordered  Unnamed: 0_y     aisle_id  \
# count        1421.000000  1421.000000   1421.000000  1421.000000
# mean            7.957072     0.592540  22781.394792   105.567910
# std             6.614026     0.491535   3656.380176     7.245139
# min             1.000000     0.000000  21554.000000    84.000000
# 25%             3.000000     0.000000  21554.000000   108.000000
# 50%             6.000000     1.000000  21554.000000   108.000000
# 75%            11.000000     1.000000  21554.000000   108.000000
# max            58.000000     1.000000  33666.000000   108.000000
#
#        department_id        prices    max_order
# count         1421.0   1421.000000  1421.000000
# mean            16.0  23523.684729    26.591133
# std              0.0  25689.753685    21.722732
# min             16.0  14900.000000     3.000000
# 25%             16.0  14900.000000    11.000000
# 50%             16.0  14900.000000    20.000000
# 75%             16.0  14900.000000    38.000000
# max             16.0  99999.000000    99.000000

# %%
#Observation: Incredibly high prices (14.900 and 99.999) both from the department_id 16 with product_id 21553 and 33664

# %%
# Find the product_name with product_id 21553 and 33664

df_orders_products_merged.loc[df_orders_products_merged['product_id'].isin([21553, 33664])]
# Out:
#          Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 3075482           171           171    912404       17    prior            12
# 3075483           181           181    603376       17    prior            22
# 3075484          1944          1944   3264360      135    prior             2
# 3075485          1945          1945    892534      135    prior             3
# 3075486          5708          5708    229704      342    prior             8
# ...               ...           ...       ...      ...      ...           ...
# 8934526        971897        971897   1129338    58405    prior            13
# 8934527        971899        971899    190064    58405    prior            15
# 8934528        971900        971900   1842539    58405    prior            16
# 8934529        974998        974998    245547    58599    prior            18
# 8934530       1045518       1045518    795062    62917    prior            20
#
#          order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 3075482          2                 14                     5.0       21553
# 3075483          6                 16                     4.0       21553
# 3075484          2                 21                    13.0       21553
# 3075485          0                  8                    12.0       21553
# 3075486          1                 19                    30.0       21553
# ...            ...                ...                     ...         ...
# 8934526          1                 10                    29.0       33664
# 8934527          5                 17                    26.0       33664
# 8934528          0                 16                    30.0       33664
# 8934529          0                 21                     6.0       33664
# 8934530          5                 12                     7.0       33664
#
#          ...  aisle_id  department_id   prices  true     price_range_loc  \
# 3075482  ...       108             16  14900.0  both  High-range product
# 3075483  ...       108             16  14900.0  both  High-range product
# 3075484  ...       108             16  14900.0  both  High-range product
# 3075485  ...       108             16  14900.0  both  High-range product
# 3075486  ...       108             16  14900.0  both  High-range product
# ...      ...       ...            ...      ...   ...                 ...
# 8934526  ...        84             16  99999.0  both  High-range product
# 8934527  ...        84             16  99999.0  both  High-range product
# 8934528  ...        84             16  99999.0  both  High-range product
# 8934529  ...        84             16  99999.0  both  High-range product
# 8934530  ...        84             16  99999.0  both  High-range product
#
#             busiest_day    busiest_days busiest_period_of_day max_order  \
# 3075482  Regularly busy  Regularly days           Most orders        40
# 3075483  Regularly busy  Regularly days        Average orders        40
# 3075484  Regularly busy  Regularly days        Average orders         4
# 3075485     Busiest day    Busiest days        Average orders         4
# 3075486  Regularly busy    Busiest days        Average orders        16
# ...                 ...             ...                   ...       ...
# 8934526  Regularly busy    Busiest days           Most orders        17
# 8934527  Regularly busy  Regularly days        Average orders        17
# 8934528     Busiest day    Busiest days        Average orders        17
# 8934529     Busiest day    Busiest days        Average orders        18
# 8934530  Regularly busy  Regularly days           Most orders        24
#
#              loyalty_flag
# 3075482  Regular customer
# 3075483  Regular customer
# 3075484      New customer
# 3075485      New customer
# 3075486  Regular customer
# ...                   ...
# 8934526  Regular customer
# 8934527  Regular customer
# 8934528  Regular customer
# 8934529  Regular customer
# 8934530  Regular customer
#
# [1421 rows x 24 columns]

# %%
#Observation:
#1. The price of 14.900 comes from Lowfat 2% Milkfat Cottage Cheese (with product_id 21553)
#2. The price of 99.999 comes from 2 % Reduced Fat Milk (with product_id 33664)

# %%
# Create a filter 'dairy' for records with the department_id value of 16, 
# and then 'dairy_without_weird' to exclude records (without very high prices)
# using ~ to exclude the data

dairy = df_orders_products_merged.loc[df_orders_products_merged['department_id'].isin([16])]
dairy_without_weird = dairy.loc[~dairy['prices'].isin([99999, 14900])]
print('Filter for records with the department_id value of 16, while excluding records without the unusually high prices:')
dairy_without_weird.sample(5)
# Out:
# Filter for records with the department_id value of 16, while excluding records without the unusually high prices:
#          Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 7463775        161845        161845   1962354     9742    prior             2
# 6190668        214167        214167    928719    12936    prior             8
# 4909038        333486        333486    703621    20185    prior            23
# 2506321        387966        387966    647125    23307    prior             5
# 6042908        340896        340896   1487835    20646    prior             3
#
#          order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 7463775          5                 13                    10.0       38672
# 6190668          2                 22                     5.0        9955
# 4909038          0                 20                     7.0        5785
# 2506321          2                 15                     8.0       18465
# 6042908          3                 15                     5.0       34668
#
#          ...  aisle_id  department_id  prices  true    price_range_loc  \
# 7463775  ...        53             16    13.0  both  Mid-range product
# 6190668  ...        91             16    11.5  both  Mid-range product
# 4909038  ...        84             16     7.9  both  Mid-range product
# 2506321  ...        86             16    13.3  both  Mid-range product
# 6042908  ...        86             16    11.7  both  Mid-range product
#
#             busiest_day    busiest_days busiest_period_of_day max_order  \
# 7463775  Regularly busy  Regularly days           Most orders         6
# 6190668  Regularly busy  Regularly days        Average orders        31
# 4909038     Busiest day    Busiest days        Average orders        50
# 2506321  Regularly busy  Regularly days           Most orders        17
# 6042908  Regularly busy    Slowest days           Most orders         9
#
#              loyalty_flag
# 7463775      New customer
# 6190668  Regular customer
# 4909038    Loyal customer
# 2506321  Regular customer
# 6042908      New customer
#
# [5 rows x 24 columns]

# %%
# Check to see if the filter is working properly

print('Maximum price in the dairy_without_weird filter:')
dairy_without_weird['prices'].max()
# Out:
# Maximum price in the dairy_without_weird filter:
# 15.0

# %%
#Observation: After excluding unusual values, the max price becomes more reasonable

# %%
# First: Observation on 2 % Reduced Fat Milk (with product_id 33664)
# Create a filter for products that contain 'Reduced Fat', '2' and 'Milk' in the name, in dairy_without_weird

reduced_fat_milk = dairy_without_weird.query('product_name.str.contains("Reduced Fat") & product_name.str.contains("2") & product_name.str.contains("Milk")')

# %%
print('Sample output from reduced_fat_milk:')
reduced_fat_milk.sample(10)
# Out:
# Sample output from reduced_fat_milk:
#          Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 6379909        169144        169144   3239013    10218    prior            53
# 4912048        552927        552927   1374385    33340    prior            37
# 3945486       1045254       1045254   1490585    62901    prior             8
# 4906784        170333        170333   1086995    10287    prior             4
# 3965279        413876        413876   2089040    24910    prior            23
# 4463960        931303        931303   2456394    55849    prior             5
# 5008700        165582        165582   1603852     9997    prior             5
# 4456753        255589        255589   3063354    15499    prior            14
# 4459697        530058        530058   1041659    31966    prior            13
# 3587007        722417        722417   2700921    43491    prior            24
#
#          order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 6379909          6                 17                     3.0        2962
# 4912048          1                 14                     3.0        5785
# 3945486          5                  8                    30.0        1940
# 4906784          0                 15                    30.0        5785
# 3965279          0                 19                     6.0       35914
# 4463960          1                 13                    18.0       23909
# 5008700          3                 13                    14.0       40174
# 4456753          6                 12                     8.0       23909
# 4459697          1                 17                     7.0       23909
# 3587007          5                 13                     6.0       32478
#
#          ...  aisle_id  department_id  prices  true    price_range_loc  \
# 6379909  ...        84             16     2.7  both  Low-range product
# 4912048  ...        84             16     7.9  both  Mid-range product
# 3945486  ...        84             16     9.1  both  Mid-range product
# 4906784  ...        84             16     7.9  both  Mid-range product
# 3965279  ...        84             16     3.3  both  Low-range product
# 4463960  ...        84             16     9.2  both  Mid-range product
# 5008700  ...        84             16    11.4  both  Mid-range product
# 4456753  ...        84             16     9.2  both  Mid-range product
# 4459697  ...        84             16     9.2  both  Mid-range product
# 3587007  ...        84             16    13.9  both  Mid-range product
#
#             busiest_day    busiest_days busiest_period_of_day max_order  \
# 6379909  Regularly busy  Regularly days        Average orders        84
# 4912048  Regularly busy    Busiest days           Most orders        75
# 3945486  Regularly busy  Regularly days        Average orders        18
# 4906784     Busiest day    Busiest days           Most orders         8
# 3965279     Busiest day    Busiest days        Average orders        25
# 4463960  Regularly busy    Busiest days           Most orders        31
# 5008700  Regularly busy    Slowest days           Most orders         9
# 4456753  Regularly busy  Regularly days           Most orders        21
# 4459697  Regularly busy    Busiest days        Average orders        13
# 3587007  Regularly busy  Regularly days           Most orders        54
#
#              loyalty_flag
# 6379909    Loyal customer
# 4912048    Loyal customer
# 3945486  Regular customer
# 4906784      New customer
# 3965279  Regular customer
# 4463960  Regular customer
# 5008700      New customer
# 4456753  Regular customer
# 4459697  Regular customer
# 3587007    Loyal customer
#
# [10 rows x 24 columns]

# %%
# Quick statistics in reduced_fat_milk

print('Quick statistics in reduced_fat_milk:')
reduced_fat_milk.describe()
# Out:
# Quick statistics in reduced_fat_milk:
#        Unnamed: 0.1  Unnamed: 0_x      order_id       user_id  order_number  \
# count  6.174000e+04  6.174000e+04  6.174000e+04  61740.000000  61740.000000
# mean   5.212328e+05  5.212328e+05  1.710790e+06  31380.634580     18.567169
# std    3.009518e+05  3.009518e+05  9.880912e+05  18062.978073     18.215726
# min    9.100000e+01  9.100000e+01  2.200000e+01     11.000000      1.000000
# 25%    2.627872e+05  2.627872e+05  8.553858e+05  15936.000000      5.000000
# 50%    5.193345e+05  5.193345e+05  1.708720e+06  31303.000000     12.000000
# 75%    7.755615e+05  7.755615e+05  2.565298e+06  46607.000000     26.000000
# max    1.048477e+06  1.048477e+06  3.420892e+06  63089.000000     99.000000
#
#           order_dow  order_hour_of_day  days_since_prior_order    product_id  \
# count  61740.000000       61740.000000            58169.000000  61740.000000
# mean       2.738306          13.167153               10.577662  18863.596566
# std        2.035715           4.185825                8.343095  13507.278252
# min        0.000000           0.000000                0.000000   1940.000000
# 25%        1.000000          10.000000                5.000000   5785.000000
# 50%        3.000000          13.000000                7.000000  19820.000000
# 75%        5.000000          16.000000               14.000000  32478.000000
# max        6.000000          23.000000               30.000000  49319.000000
#
#        add_to_cart_order     reordered  Unnamed: 0_y      aisle_id  \
# count       61740.000000  61740.000000  61740.000000  61740.000000
# mean            5.428814      0.784208  18864.751393     83.632653
# std             5.395368      0.411374  13508.581040      6.892654
# min             1.000000      0.000000   1940.000000     21.000000
# 25%             2.000000      1.000000   5785.000000     84.000000
# 50%             4.000000      1.000000  19821.000000     84.000000
# 75%             7.000000      1.000000  32480.000000     84.000000
# max            73.000000      1.000000  49323.000000     91.000000
#
#        department_id        prices     max_order
# count        61740.0  61740.000000  61740.000000
# mean            16.0      9.116113     35.470279
# std              0.0      3.057663     25.702041
# min             16.0      1.200000      3.000000
# 25%             16.0      7.900000     15.000000
# 50%             16.0      9.200000     30.000000
# 75%             16.0     11.400000     50.000000
# max             16.0     14.700000     99.000000

# %%
#Observation: Now the mean, min and max prices for products that contain 'Reduced Fat', '2' and 'Milk' in the name are: 9.08, 1.2, 14.7. Since this result makes more sense, the price of product ID 33664, named '2 % Reduced Fat Milk' will be reduced from 99.999 to 9.99¶

# %%
# Second: Observation on Lowfat 2% Milkfat Cottage Cheese (with product_id 21553)
# Create a filter for products that contain 'Cottage Cheese', '2' and 'Milkfat' in the name, in dairy_without_weird

cottage_cheese = dairy_without_weird.query('product_name.str.contains("Cottage Cheese") & product_name.str.contains("2") & product_name.str.contains("Milkfat")')

# %%
print('Sample output from cottage_cheese:')
cottage_cheese.sample(10)
# Out:
# Sample output from cottage_cheese:
#          Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 4965012       1004501       1004501     49417    60363    prior            13
# 4964754        498585        498585   1506795    30070    prior             8
# 9368015       1018556       1018556   1882247    61220    prior            86
# 4964604        334973        334973   1741765    20285    prior            10
# 9159502        746853        746853   2702487    44951    prior            27
# 4964793        557168        557168   1710385    33585    prior            15
# 4965031       1042053       1042053   3308190    62730    prior             5
# 9367956        163025        163025   2051860     9825    prior            20
# 9367988        429964        429964   1423722    25849    prior             2
# 4964640        374395        374395    459561    22539    prior            19
#
#          order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 4965012          3                 22                    10.0       27790
# 4964754          2                 10                    22.0       27790
# 9368015          6                 19                     3.0       11203
# 4964604          1                 15                    24.0       27790
# 9159502          0                 13                    19.0        6852
# 4964793          6                  8                     2.0       27790
# 4965031          6                  9                    30.0       27790
# 9367956          0                 17                    18.0       11203
# 9367988          2                 20                     7.0       11203
# 4964640          1                 12                    22.0       27790
#
#          ...  aisle_id  department_id  prices  true    price_range_loc  \
# 4965012  ...       108             16     7.7  both  Mid-range product
# 4964754  ...       108             16     7.7  both  Mid-range product
# 9368015  ...       108             16     2.4  both  Low-range product
# 4964604  ...       108             16     7.7  both  Mid-range product
# 9159502  ...       108             16     8.6  both  Mid-range product
# 4964793  ...       108             16     7.7  both  Mid-range product
# 4965031  ...       108             16     7.7  both  Mid-range product
# 9367956  ...       108             16     2.4  both  Low-range product
# 9367988  ...       108             16     2.4  both  Low-range product
# 4964640  ...       108             16     7.7  both  Mid-range product
#
#             busiest_day    busiest_days busiest_period_of_day max_order  \
# 4965012  Regularly busy    Slowest days        Average orders        14
# 4964754  Regularly busy  Regularly days           Most orders        12
# 9368015  Regularly busy  Regularly days        Average orders        94
# 4964604  Regularly busy    Busiest days           Most orders        10
# 9159502     Busiest day    Busiest days           Most orders        29
# 4964793  Regularly busy  Regularly days        Average orders        20
# 4965031  Regularly busy  Regularly days        Average orders         6
# 9367956     Busiest day    Busiest days        Average orders        30
# 9367988  Regularly busy  Regularly days        Average orders        10
# 4964640  Regularly busy    Busiest days           Most orders        24
#
#              loyalty_flag
# 4965012  Regular customer
# 4964754  Regular customer
# 9368015    Loyal customer
# 4964604      New customer
# 9159502  Regular customer
# 4964793  Regular customer
# 4965031      New customer
# 9367956  Regular customer
# 9367988      New customer
# 4964640  Regular customer
#
# [10 rows x 24 columns]

# %%
# Quick statistics in cottage_cheese

print('Quick statistics in cottage_cheese:')
cottage_cheese.describe()
# Out:
# Quick statistics in cottage_cheese:
#        Unnamed: 0.1  Unnamed: 0_x      order_id       user_id  order_number  \
# count  9.560000e+02  9.560000e+02  9.560000e+02    956.000000    956.000000
# mean   4.532606e+05  4.532606e+05  1.697755e+06  27296.542887     14.274059
# std    2.962718e+05  2.962718e+05  9.512639e+05  17789.915053     15.418022
# min    7.740000e+02  7.740000e+02  2.301000e+03     52.000000      1.000000
# 25%    1.865262e+05  1.865262e+05  9.148818e+05  11273.250000      4.000000
# 50%    4.156235e+05  4.156235e+05  1.681580e+06  25025.000000      9.000000
# 75%    7.213185e+05  7.213185e+05  2.445081e+06  43424.750000     19.000000
# max    1.047950e+06  1.047950e+06  3.419042e+06  63069.000000     97.000000
#
#         order_dow  order_hour_of_day  days_since_prior_order    product_id  \
# count  956.000000         956.000000              883.000000    956.000000
# mean     2.758368          13.063808               13.528879  23017.456067
# std      2.023729           4.642069                9.432299   8353.952061
# min      0.000000           0.000000                0.000000    195.000000
# 25%      1.000000          10.000000                6.000000  16257.000000
# 50%      3.000000          13.000000               11.000000  27790.000000
# 75%      5.000000          16.000000               21.000000  27790.000000
# max      6.000000          23.000000               30.000000  31030.000000
#
#        add_to_cart_order   reordered  Unnamed: 0_y    aisle_id  department_id  \
# count          956.00000  956.000000    956.000000  956.000000          956.0
# mean             5.34205    0.680962  23018.920502  107.908996           16.0
# std              5.03861    0.466348   8354.832662    2.813781            0.0
# min              1.00000    0.000000    194.000000   21.000000           16.0
# 25%              2.00000    0.000000  16257.000000  108.000000           16.0
# 50%              4.00000    1.000000  27792.000000  108.000000           16.0
# 75%              7.00000    1.000000  27792.000000  108.000000           16.0
# max             41.00000    1.000000  31032.000000  108.000000           16.0
#
#            prices   max_order
# count  956.000000  956.000000
# mean     7.204707   28.125523
# std      1.675324   24.569187
# min      2.400000    3.000000
# 25%      7.700000   10.000000
# 50%      7.700000   20.000000
# 75%      7.700000   39.000000
# max     11.800000   99.000000

# %%
#Observation: Now the mean, min and max prices for products that contain 'Cottage Cheese', '2' and 'Milkfat' in the name are: 7.23, 2.4, 11.8. Since this result makes more sense, the price of product ID 21553, named 'Lowfat 2% Milkfat Cottage Cheese' will be replaced from 14.900 and inputed by the mean value mentioned above

# %%
# Replace the price '99999' with '9.99' and impute the value '14900' with the mean price from cottage_cheese

df_orders_products_merged['prices'] = df_orders_products_merged['prices'].replace({99999: 9.99, 14900: cottage_cheese['prices'].mean()})

# %%
# Check the statistics of the new 'prices' column in df_orders_products_merged

print('The statistics of the new prices column in df_orders_products_merged:')
df_orders_products_merged['prices'].describe()
# Out:
# The statistics of the new prices column in df_orders_products_merged:
# count    9.918253e+06
# mean     7.791102e+00
# std      4.241473e+00
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      2.500000e+01
# Name: prices, dtype: float64

# %%
#Observation: Now the mean, std, min and max results make more sense

# %%
#Step 5 (Updated: After this step --> replace({99999: 9.99, 14900: cottage_cheese['prices'].mean())

# %%
#Determine the difference between the spending habits of the three types of customers you identified.
#Determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers

# %%
# Basic statistics of df_orders_products_merged by 'loyalty_flag' with the updated 'prices' column

print('The mean, min and max of prices grouped by loyalty_flag with the updated prices column in df_orders_products_merged:')
df_orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# The mean, min and max of prices grouped by loyalty_flag with the updated prices column in df_orders_products_merged:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.767695  1.0  25.0
# New customer      7.809452  1.0  25.0
# Regular customer  7.799116  1.0  25.0

# %%
#Observation: Although the result remains the same, new customer holds the highest purchase price followed by regular customer then loyal customer, now the mean value becomes lower and max value is more reasonable (instead of 99999, now 25)¶

# %%
#STEP 6
#Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %%
1. #If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
2. #If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”
# Out:
# 2.0

# %%
# Creating “average_price” column using transform()

df_orders_products_merged['average_price'] = df_orders_products_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#    department_id  prices  true    price_range_loc     busiest_day  \
# 0              7     9.0  both  Mid-range product  Regularly busy
# 1              7     9.0  both  Mid-range product  Regularly busy
# 2              7     9.0  both  Mid-range product  Regularly busy
# 3              7     9.0  both  Mid-range product      Least busy
# 4              7     9.0  both  Mid-range product      Least busy
#
#      busiest_days  busiest_period_of_day max_order  loyalty_flag average_price
# 0  Regularly days         Average orders        10  New customer      6.367797
# 1    Slowest days         Average orders        10  New customer      6.367797
# 2    Slowest days            Most orders        10  New customer      6.367797
# 3    Slowest days         Average orders        10  New customer      6.367797
# 4    Slowest days            Most orders        10  New customer      6.367797
#
# [5 rows x 25 columns]

# %%
# Creating a 'spending_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Creating a 'spending_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#    prices  true    price_range_loc     busiest_day    busiest_days  \
# 0     9.0  both  Mid-range product  Regularly busy  Regularly days
# 1     9.0  both  Mid-range product  Regularly busy    Slowest days
# 2     9.0  both  Mid-range product  Regularly busy    Slowest days
# 3     9.0  both  Mid-range product      Least busy    Slowest days
# 4     9.0  both  Mid-range product      Least busy    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag average_price spending_flag
# 0         Average orders         10  New customer      6.367797   Low spender
# 1         Average orders         10  New customer      6.367797   Low spender
# 2            Most orders         10  New customer      6.367797   Low spender
# 3         Average orders         10  New customer      6.367797   Low spender
# 4            Most orders         10  New customer      6.367797   Low spender
#
# [5 rows x 26 columns]

# %%
# Check the frequency

df_orders_products_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     9881809
# High spender      36444
# Name: spending_flag, dtype: int64

# %%
#Step 7

# %%
#Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#1. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#2. If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#3. If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Creating “median_prior_orders” column using transform()

df_orders_products_merged['median_prior_orders'] = df_orders_products_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#    true    price_range_loc     busiest_day    busiest_days  \
# 0  both  Mid-range product  Regularly busy  Regularly days
# 1  both  Mid-range product  Regularly busy    Slowest days
# 2  both  Mid-range product  Regularly busy    Slowest days
# 3  both  Mid-range product      Least busy    Slowest days
# 4  both  Mid-range product      Least busy    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag average_price spending_flag  \
# 0         Average orders         10  New customer      6.367797   Low spender
# 1         Average orders         10  New customer      6.367797   Low spender
# 2            Most orders         10  New customer      6.367797   Low spender
# 3         Average orders         10  New customer      6.367797   Low spender
# 4            Most orders         10  New customer      6.367797   Low spender
#
#   median_prior_orders
# 0                20.5
# 1                20.5
# 2                20.5
# 3                20.5
# 4                20.5
#
# [5 rows x 27 columns]

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[(df_orders_products_merged['median_prior_orders'] > 10) & (df_orders_products_merged['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating a 'order_frequency_flag' flag

df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          3                  7                    15.0         196  ...
# 2          3                 12                    21.0         196  ...
# 3          4                  7                    29.0         196  ...
# 4          4                 15                    28.0         196  ...
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly days        Average orders
# 1  Mid-range product  Regularly busy    Slowest days        Average orders
# 2  Mid-range product  Regularly busy    Slowest days           Most orders
# 3  Mid-range product      Least busy    Slowest days        Average orders
# 4  Mid-range product      Least busy    Slowest days           Most orders
#
#    max_order  loyalty_flag  average_price spending_flag median_prior_orders  \
# 0         10  New customer       6.367797   Low spender                20.5
# 1         10  New customer       6.367797   Low spender                20.5
# 2         10  New customer       6.367797   Low spender                20.5
# 3         10  New customer       6.367797   Low spender                20.5
# 4         10  New customer       6.367797   Low spender                20.5
#
#     order_frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
#
# [5 rows x 28 columns]

# %%
# Check the frequency

df_orders_products_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        6582166
# Regular customer         2226335
# Non-frequent customer    1109752
# Name: order_frequency_flag, dtype: int64

# %%
# Check the null values

print('Records in df_orders_products_merged with null values in column order_frequency_flag:')
df_orders_products_merged[df_orders_products_merged['order_frequency_flag'].isnull()][['user_id', 'days_since_prior_order', 'median_prior_orders', 'order_frequency_flag']]
# Out:
# Records in df_orders_products_merged with null values in column order_frequency_flag:
# Empty DataFrame
# Columns: [user_id, days_since_prior_order, median_prior_orders, order_frequency_flag]
# Index: []

# %%
# Check user_id 159838

df_orders_products_merged[df_orders_products_merged['user_id'] == 159838]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0_x, order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, Unnamed: 0_y, product_name, aisle_id, department_id, prices, true, price_range_loc, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag, average_price, spending_flag, median_prior_orders, order_frequency_flag]
# Index: []
#
# [0 rows x 28 columns]

# %%
df_orders_products_merged.shape
# Out:
# (9918253, 28)

# %%
### Note to tutor: I guess there were some missing rows related to User Id: 159838 which have been deleted by me by mistake

# %%
#Step 8

# %%
#Ensure your notebook is clean and structured and that your code is well commented.

# %%
#Step 9

# %%
df_orders_products_merged.to_pickle(os.path.join(path,'Prepared', 'orders_products_merged_updated_2.pkl'))

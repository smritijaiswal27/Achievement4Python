# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\smrit\Intracart basket'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Prepared', 'orders_products_combined.pkl'))

# %%
# Import products_checked.csv
df_prods = pd.read_csv(os.path.join(path, 'Prepared', 'products_checked.csv'), index_col = False)

# %%
# Step 4. Check the shape of the imported dataframe (it should be the same as the one you exported:
df_orders_products_combined.shape
# Out:
# (9927471, 13)

# %%
# Check output for df_orders_products_combined
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# 3                  4          0   both
# 4                  5          0   both

# %%
# Check df_prods size
df_prods.shape
# Out:
# (49672, 6)

# %%
# Check output for df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop unnamed column for df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Step 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set:
df_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = 'true')

# %%
# Check output for df_merged
df_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          3                  7                    15.0         196
# 2          3                 12                    21.0         196
# 3          4                  7                    29.0         196
# 4          4                 15                    28.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          0         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
#
#    true
# 0  both
# 1  both
# 2  both
# 3  both
# 4  both

# %%
# Step 6. Confirm the results of the merge using the merge flag:
df_merged['true'].value_counts()
# Out:
# both          9918253
# left_only           0
# right_only          0
# Name: true, dtype: int64

# %%
# Step 7. Export the newly created dataframe as orders_products_merged in a suitable format:
df_merged.to_pickle(os.path.join(path,'Prepared', 'orders_products_merged.pkl'))

# %%
# Drop '_merge' column for df_orders_products_combined
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

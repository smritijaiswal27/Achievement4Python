# %%
import pandas as pd
import numpy as np
import os

# %%
###Task 2
path=r'C:\Users\smrit\OneDrive\Desktop\Intracart Basket analysis'

# %%
df_ords = pd.read_csv(os.path.join(path,'Scripts','Order.csv'))

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
###Task 3
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
###Task 4

df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    88228
# 11    87087
# 14    86905
# 15    86888
# 13    85652
# 12    84204
# 16    83421
# 9     78737
# 17    69960
# 18    56284
# 8     54868
# 19    43076
# 20    31735
# 7     28199
# 21    23972
# 22    18824
# 23    12112
# 6      9253
# 0      6881
# 1      3698
# 5      2882
# 2      2312
# 4      1748
# 3      1649
# Name: order_hour_of_day, dtype: int64

# %%
####Busiest hour is 10 am

# %%
####Data Wrangling Procedures

# %%
# dropping eval_set from orders.csv
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# check if the eval_set is dropped
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# displaying missing value in days_since_prior_order column 
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    112498
# 7.0      98756
# 6.0      73424
# 4.0      67774
# 3.0      66728
# 5.0      65969
# NaN      63100
# 2.0      59256
# 8.0      55759
# 1.0      44010
# 9.0      36115
# 14.0     30802
# 10.0     29562
# 13.0     25552
# 11.0     24763
# 12.0     23600
# 0.0      20627
# 15.0     20620
# 16.0     14487
# 21.0     13829
# 17.0     12048
# 20.0     11722
# 18.0     11047
# 19.0     10682
# 22.0      9787
# 28.0      7999
# 23.0      7282
# 27.0      6770
# 24.0      6362
# 25.0      5943
# 26.0      5883
# 29.0      5819
# Name: days_since_prior_order, dtype: int64

# %%
# renaming order_dow column 
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
# checking the new column
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# changing data type of order_id column
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# checking data type of oder_id column
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
path = r'C:\Users\smrit\Intracart basket'

# %%
path
# Out:
# 'C:\\Users\\smrit\\Intracart basket'

# %%
# importing department.csv
df_dep = pd.read_csv(os.path.join(path,'Data', 'Department.csv'), index_col = False)

# %%
# checking columns of departments.csv
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# transforming df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# creating a new dataframe
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# adding an index 
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# take the first row of df_dpt_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# take the data under the header row for a new df
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# set new_header for new df
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# create a data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
path
# Out:
# 'C:\\Users\\smrit\\Intracart basket'

# %%
# importing products dtata (using os library)
df_prods =  pd.read_csv(os.path.join(path, 'Data', 'products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# check values within df_prods that have a "department_id" of 19 and create a new df called df_snacks
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
#####Task 2 to 13

# %%
# 2. changing data type of user_id column
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# checking data type of user_id column
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %%
# 3. change column name without overwriting the data frame.
df_ords.rename(columns = {'days_since_prior_order' : 'days_since_previous_order'}, inplace = False)
# Out:
#          order_id user_id eval_set  order_number  order_dow  \
# 0         2539329       1    prior             1          2
# 1         2398795       1    prior             2          3
# 2          473747       1    prior             3          3
# 3         2254736       1    prior             4          4
# 4          431534       1    prior             5          4
# ...           ...     ...      ...           ...        ...
# 1048570   1805240   63100    prior             1          0
# 1048571   2719402   63100    prior             2          0
# 1048572   2855250   63100    prior             3          2
# 1048573   2355832   63100    prior             4          5
# 1048574   2362552   63100    train             5          1
#
#          order_hour_of_day  days_since_previous_order
# 0                        8                        NaN
# 1                        7                       15.0
# 2                       12                       21.0
# ...

# %%
# 4. The busiest hour is for placing orders
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    88228
# 11    87087
# 14    86905
# 15    86888
# 13    85652
# 12    84204
# 16    83421
# 9     78737
# 17    69960
# 18    56284
# 8     54868
# 19    43076
# 20    31735
# 7     28199
# 21    23972
# 22    18824
# 23    12112
# 6      9253
# 0      6881
# 1      3698
# 5      2882
# 2      2312
# 4      1748
# 3      1649
# Name: order_hour_of_day, dtype: int64

# %%
###The busiest hour for palcing orders is 10 am (288418)

# %%
# 5. Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# 6. Create a subset about breakfast item sales.
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# 7. items from the following departments: alcohol, deli, beverages, and meat/seafood
df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# 9. Extract all the information about this user with a "user_id" of “1.
df_ords_user1 = df_ords[df_ords['user_id']=='1']

# %%
df_ords_user1
# Out:
#     order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329       1    prior             1          2                  8
# 1    2398795       1    prior             2          3                  7
# 2     473747       1    prior             3          3                 12
# 3    2254736       1    prior             4          4                  7
# 4     431534       1    prior             5          4                 15
# 5    3367565       1    prior             6          2                  7
# 6     550135       1    prior             7          1                  9
# 7    3108588       1    prior             8          1                 14
# 8    2295261       1    prior             9          1                 16
# 9    2550362       1    prior            10          4                  8
# 10   1187899       1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# ...

# %%
# 10. basic stats
df_ords_user1.describe()
# Out:
#            order_id  order_number  order_dow  order_hour_of_day  \
# count  1.100000e+01     11.000000  11.000000          11.000000
# mean   1.923450e+06      6.000000   2.636364          10.090909
# std    1.071950e+06      3.316625   1.286291           3.477198
# min    4.315340e+05      1.000000   1.000000           7.000000
# 25%    8.690170e+05      3.500000   1.500000           7.500000
# 50%    2.295261e+06      6.000000   3.000000           8.000000
# 75%    2.544846e+06      8.500000   4.000000          13.000000
# max    3.367565e+06     11.000000   4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
path
# Out:
# 'C:\\Users\\smrit\\Intracart basket'

# %%
df_ords.to_csv(os.path.join(path,'Prepared', 'Ordered_Wrangled.csv'))

# %%
# 13. Export df_dep_t_new
df_dep_t_new.to_csv(os.path.join(path, 'Prepared', 'departments_wrangled.csv'))
